# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# !nvidia-smi
# Out:
# Sat Mar 18 17:43:42 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   56C    P0    29W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Install YOLOv8
#
# ⚠️ YOLOv8 is still under heavy development. Breaking changes are being introduced almost weekly. We strive to make our YOLOv8 notebooks work with the latest version of the library. Last tests took place on **27.01.2023** with version **YOLOv8.0.20**.
#
# If you notice that our notebook behaves incorrectly - especially if you experience errors that prevent you from going through the tutorial - don't hesitate! Let us know and open an [issue](https://github.com/roboflow/notebooks/issues) on the Roboflow Notebooks repository.
#
# YOLOv8 can be installed in two ways - from the source and via pip. This is because it is the first iteration of YOLO to have an official package.

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.0.20

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 25.5/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# If you want to train, validate or run inference on models and don't need to make any modifications to the code, using YOLO command line interface is the easiest way to get started. Read more about CLI in [Ultralytics YOLO Docs](https://v8docs.ultralytics.com/cli/).
#
# ```
# yolo task=detect    mode=train    model=yolov8n.yaml      args...
#           classify       predict        yolov8n-cls.yaml  args...
#           segment        val            yolov8n-seg.yaml  args...
#                          export         yolov8n.pt        format=onnx  args...
# ```

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %% [markdown]
# `yolo mode=predict` runs YOLOv8 inference on a variety of sources, downloading models automatically from the latest YOLOv8 release, and saving results to `runs/predict`.

# %%
# Without preprocess
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow --quiet

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Nz5FjYhFGviCKM4DIvLK")
project = rf.workspace("fyp-dgvrc").project("fish-biomass-estimation-v8")
dataset = project.version(1).download("yolov8")
# Out:
# /content/datasets
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.7/55.7 KB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 KB 8.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 KB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 KB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 KB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Fish-biomass-estimation-v8-1 in yolov8:: 100%|██████████| 9162/9162 [00:02<00:00, 3927.27it/s]

# %%
# %cd {HOME}
# %ls
# %cd {HOME}/gdrive/MyDrive/yolov8
# Out:
# /content/gdrive/MyDrive/yolov8

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}/gdrive/MyDrive/yolov8

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=800 plots=True save_txt=True
# Out:
# /content/gdrive/MyDrive/yolov8
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls {HOME}/gdrive/MyDrive/yolov8/runs/detect/train6/
# Out:
# args.yaml					    train_batch2.jpg
# confusion_matrix.png				    train_batch3015.jpg
# events.out.tfevents.1679161543.fd8b931cac29.2055.0  train_batch3016.jpg
# F1_curve.png					    train_batch3017.jpg
# labels						    val_batch0_labels.jpg
# P_curve.png					    val_batch0_pred.jpg
# PR_curve.png					    val_batch1_labels.jpg
# R_curve.png					    val_batch1_pred.jpg
# results.csv					    val_batch2_labels.jpg
# results.png					    val_batch2_pred.jpg
# train_batch0.jpg				    weights
# train_batch1.jpg

# %%
# %cd {HOME}/gdrive/MyDrive/yolov8
Image(filename=f'{HOME}/gdrive/MyDrive/yolov8/runs/detect/train6/confusion_matrix.png', width=600)
# Out:
# /content/gdrive/MyDrive/yolov8

# %%
# %cd {HOME}/gdrive/MyDrive/yolov8
Image(filename=f'{HOME}/gdrive/MyDrive/yolov8/runs/detect/train6/results.png', width=600)
# Out:
# /content/gdrive/MyDrive/yolov8

# %%
# %cd {HOME}/gdrive/MyDrive/yolov8
Image(filename=f'{HOME}/gdrive/MyDrive/yolov8/runs/detect/train6/val_batch0_pred.jpg', width=600)
# Out:
# /content/gdrive/MyDrive/yolov8

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}/gdrive/MyDrive/yolov8

# !yolo task=detect mode=val model={HOME}/gdrive/MyDrive/yolov8/runs/detect/train6/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content/gdrive/MyDrive/yolov8
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/datasets/Fish-biomass-estimation-v8-1/valid/labels.cache... 915 images, 0 backgrounds, 0 corrupt: 100% 915/915 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 58/58 [00:24<00:00,  2.37it/s]
#                    all        915       2195      0.996      0.995      0.995      0.927
#                      0        915        898          1      0.993      0.995      0.965
#                      1        915        623          1      0.998      0.995      0.927
#                      2        915        674       0.99      0.992      0.995      0.888
# Speed: 1.0ms pre-process, 13.3ms inference, 0.0ms loss, 2.1ms post-process per image

# %% [markdown]
# ## Inference with Custom Model

# %%
# %cd {HOME}/gdrive/MyDrive/yolov8
# !yolo task=detect mode=predict model={HOME}/gdrive/MyDrive/yolov8/runs/detect/train6/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True save_txt=True
# Out:
# /content/gdrive/MyDrive/yolov8
# Ultralytics YOLOv8.0.20 🚀 Python-3.9.16 torch-1.13.1+cu116 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11126745 parameters, 0 gradients, 28.4 GFLOPs
# image 1/458 /content/datasets/Fish-biomass-estimation-v8-1/test/images/frame_000004_PNG.rf.1f57ae55536a075ec416f63fd20d7fe7.jpg: 800x800 1 0, 1 1, 1 2, 26.1ms
# image 2/458 /content/datasets/Fish-biomass-estimation-v8-1/test/images/frame_000020_PNG.rf.dfd802eae08f9cbb8aa6700b75864bf5.jpg: 800x800 1 0, 1 1, 1 2, 26.1ms
# image 3/458 /content/datasets/Fish-biomass-estimation-v8-1/test/images/frame_000024_PNG.rf.7ccab0ddf9299eed614361fac84e23ca.jpg: 800x800 1 0, 1 1, 1 2, 26.1ms
# image 4/458 /content/datasets/Fish-biomass-estimation-v8-1/test/images/frame_000031_PNG.rf.c46d4946155eb6c32afcc90fd0fdf1a8.jpg: 800x800 1 0, 1 1, 1 2, 26.1ms
# ...

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/gdrive/MyDrive/yolov8/runs/detect/predict6/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")
